# %%
import numpy as np
import pandas as pd
import psycopg2 as pg2

# %% [markdown]
# #### Load data

# %%
df = pd.read_csv('./data/aq_state_data_2019.csv')

# %%
pd.set_option('display.max_rows', 999)
pd.set_option('display.max_columns', 999)

# %%
df.head()
# Out:
#     aqi  arithmetic_mean                   cbsa  cbsa_code        city  \
# 0  50.0         0.044417  Birmingham-Hoover, AL    13820.0  Birmingham
# 1  50.0         0.039211  Birmingham-Hoover, AL    13820.0  Birmingham
# 2  50.0         0.039211  Birmingham-Hoover, AL    13820.0  Birmingham
# 3   NaN         0.035333  Birmingham-Hoover, AL    13820.0  Birmingham
# 4  90.0         0.040706  Birmingham-Hoover, AL    13820.0  Birmingham
#
#       county  county_code  date_local date_of_last_change  datum event_type  \
# 0  Jefferson           73  2019-08-31          2020-03-10  WGS84       None
# 1  Jefferson           73  2019-08-31          2020-03-10  WGS84       None
# 2  Jefferson           73  2019-08-31          2020-03-10  WGS84       None
# 3  Jefferson           73  2019-08-31          2020-03-10  WGS84       None
# 4  Jefferson           73  2019-08-30          2020-03-10  WGS84       None
#
#    first_max_hour  first_max_value   latitude   local_site_name  longitude  \
# 0               9            0.054  33.553056  North Birmingham    -86.815
# 1               9            0.054  33.553056  North Birmingham    -86.815
# 2               9            0.054  33.553056  North Birmingham    -86.815
# 3              10            0.059  33.553056  North Birmingham    -86.815
# 4              10            0.067  33.553056  North Birmingham    -86.815
#
#                                    method  method_code  observation_count  \
# 0  INSTRUMENTAL - ULTRA VIOLET ABSORPTION         87.0                 12
# 1  INSTRUMENTAL - ULTRA VIOLET ABSORPTION         87.0                 19
# 2  INSTRUMENTAL - ULTRA VIOLET ABSORPTION         87.0                 19
# 3  INSTRUMENTAL - ULTRA VIOLET ABSORPTION         87.0                 24
# 4  INSTRUMENTAL - ULTRA VIOLET ABSORPTION         87.0                 17
#
#    observation_percent parameter  parameter_code  poc pollutant_standard  \
# 0                 71.0     Ozone           44201    1  Ozone 8-hour 2015
# 1                 79.0     Ozone           44201    1  Ozone 8-Hour 2008
# 2                 79.0     Ozone           44201    1  Ozone 8-Hour 1997
# 3                100.0     Ozone           44201    1  Ozone 1-hour 1979
# 4                100.0     Ozone           44201    1  Ozone 8-hour 2015
#
#            sample_duration                           site_address  \
# 0  8-HR RUN AVG BEGIN HOUR  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.
# 1  8-HR RUN AVG BEGIN HOUR  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.
# 2  8-HR RUN AVG BEGIN HOUR  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.
# 3                   1 HOUR  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.
# 4  8-HR RUN AVG BEGIN HOUR  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.
#
#    site_number    state  state_code   units_of_measure validity_indicator
# 0           23  Alabama           1  Parts per million                  N
# 1           23  Alabama           1  Parts per million                  Y
# 2           23  Alabama           1  Parts per million                  Y
# 3           23  Alabama           1  Parts per million                  Y
# 4           23  Alabama           1  Parts per million                  Y

# %% [markdown]
# #### Leave data that only matters: AQI of Ozone and PM2.5 at every measuring point of all states

# %%
df = df.dropna(axis=0)[df['validity_indicator'] == 'Y']\
    [['aqi', 'date_local', 'latitude', 'longitude', 'parameter', 'state']]
# Out:
# C:\Users\jjing\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df.shape
# Out:
# (2714610, 6)

# %%
df.head()
# Out:
#     aqi  date_local   latitude  longitude parameter    state
# 1  50.0  2019-08-31  33.553056    -86.815     Ozone  Alabama
# 2  50.0  2019-08-31  33.553056    -86.815     Ozone  Alabama
# 4  90.0  2019-08-30  33.553056    -86.815     Ozone  Alabama
# 5  90.0  2019-08-30  33.553056    -86.815     Ozone  Alabama
# 6  90.0  2019-08-30  33.553056    -86.815     Ozone  Alabama

# %%
df['parameter'].unique()
# Out:
# array(['Ozone', 'PM10 Total 0-10um STP', 'PM2.5 - Local Conditions',
#        'Carbon monoxide', 'Nitrogen dioxide (NO2)', 'Sulfur dioxide'],
#       dtype=object)

# %%
df = df[(df['parameter'] == 'Ozone') | (df['parameter'] == 'PM2.5 - Local Conditions')]

# %%
df['parameter'] = df['parameter'].map(lambda x: 'PM25' if x == 'PM2.5 - Local Conditions' else 'OZ')

# %%
df = df.pivot_table(index=['latitude', 'longitude', 'date_local', 'parameter', 'state'], values=['aqi'], aggfunc='mean')
df.reset_index(level=['latitude', 'longitude', 'date_local', 'parameter', 'state'], inplace=True)
df.head()
# Out:
#     latitude   longitude  date_local parameter   state   aqi
# 0  19.117561 -155.778136  2019-01-01      PM25  Hawaii  24.0
# 1  19.117561 -155.778136  2019-01-02      PM25  Hawaii  20.0
# 2  19.117561 -155.778136  2019-01-03      PM25  Hawaii  21.0
# 3  19.117561 -155.778136  2019-01-04      PM25  Hawaii  25.0
# 4  19.117561 -155.778136  2019-01-05      PM25  Hawaii  24.0

# %% [markdown]
# #### Prepare data to create tables in a database

# %%
df_point = df.pivot_table(index=['latitude', 'longitude'], values=['aqi'], aggfunc='mean')
df_point.reset_index(level=['latitude', 'longitude'], inplace=True)
df_point = df_point.drop(columns=['aqi'])
df_point['pt_id'] = [x for x in range(1482)]
df_point.tail()
# Out:
#        latitude   longitude  pt_id
# 1477  61.598898 -149.106220   1477
# 1478  64.762973 -147.310297   1478
# 1479  64.840672 -147.722461   1479
# 1480  64.845690 -147.727413   1480
# 1481  64.845930 -147.693270   1481

# %%
df = df.merge(df_point, on=['latitude', 'longitude'], how='left')[['date_local', 'parameter', 'state', 'aqi', 'pt_id']]
df.head()
# Out:
#    date_local parameter   state   aqi  pt_id
# 0  2019-01-01      PM25  Hawaii  24.0      0
# 1  2019-01-02      PM25  Hawaii  20.0      0
# 2  2019-01-03      PM25  Hawaii  21.0      0
# 3  2019-01-04      PM25  Hawaii  25.0      0
# 4  2019-01-05      PM25  Hawaii  24.0      0

# %% [markdown]
# #### Make a database

# %%
db_pwd = 'password'
conn = pg2.connect(database='AQI_2019', user='postgres', password=db_pwd)
cur = conn.cursor()

# %%
# create table
create_args = \
"""CREATE TABLE measuring_pt (
lat float NOT NULL, 
long float NOT NULL, 
pt_id integer PRIMARY KEY
)"""

cur.execute(create_args)
conn.commit()

# %%
create_args = \
"""CREATE TABLE aqi (
date VARCHAR(10) NOT NULL,
type VARCHAR(16) NOT NULL,
state VARCHAR(32) NOT NULL,
aqi float NOT NULL,
pt_id integer NOT NULL
)"""

cur.execute(create_args)
conn.commit()

# %%
# a function insert a dataframe into a table
def save_database(cursor, table, df):
    values = []
    for row in df.itertuples(index=False):
        values.append(tuple([str(x) for x in row]))
    args_str = str(values).replace('[', '').replace(']', '')
    cursor.execute("INSERT INTO " + table + " VALUES " + args_str)
    conn.commit()

# %%
save_database(cur, 'aqi', df)

# %%
save_database(cur, 'measuring_pt', df_point)

# %%
# fetch data
cur.execute("""SELECT * FROM aqi
            INNER JOIN measuring_pt ON measuring_pt.pt_id = aqi.pt_id
            WHERE aqi.date='2019-09-01'
            LIMIT 50""")
pd.DataFrame(cur.fetchall(), columns=['date', 'type', 'state', 'aqi', 'id1', 'lat', 'long', 'pt_id']).drop(columns=['id1'])
# Out:
#           date  type      state   aqi        lat       long  pt_id
# 0   2019-09-01    OZ      Texas  51.0  29.043759 -95.472946     76
# 1   2019-09-01    OZ    Florida  12.0  29.170533 -82.100646     77
# 2   2019-09-01    OZ    Florida  12.0  29.192754 -82.173149     78
# 3   2019-09-01    OZ      Texas  80.0  29.254474 -94.861289     80
# 4   2019-09-01  PM25      Texas  47.0  29.254474 -94.861289     80
# 5   2019-09-01    OZ      Texas  44.0  29.275381 -98.311692     81
# 6   2019-09-01  PM25      Texas  29.0  29.275381 -98.311692     81
# 7   2019-09-01    OZ      Texas  48.0  29.515090 -98.620166     83
# 8   2019-09-01  PM25      Texas  31.0  29.515090 -98.620166     83
# 9   2019-09-01    OZ      Texas  64.0  29.520443 -95.392509     84
# 10  2019-09-01  PM25      Texas  29.0  29.529400 -98.391390     85
# 11  2019-09-01    OZ    Florida  10.0  29.566112 -82.266080     86
# 12  2019-09-01    OZ      Texas  42.0  29.583047 -95.015544     87
# 13  2019-09-01    OZ      Texas  48.0  29.623889 -95.474167     88
# 14  2019-09-01    OZ      Texas  50.0  29.625556 -95.267222     89
# 15  2019-09-01    OZ      Texas  50.0  29.632058 -98.564936     90
# 16  2019-09-01    OZ      Texas  46.0  29.670025 -95.128508     91
# 17  2019-09-01    OZ      Texas  47.0  29.686389 -95.294722     93
# 18  2019-09-01    OZ      Texas  58.0  29.695729 -95.499219     94
# 19  2019-09-01    OZ      Texas  49.0  29.723333 -95.635833     96
# 20  2019-09-01    OZ      Texas  46.0  29.727931 -93.894081     97
# 21  2019-09-01    OZ      Texas  40.0  29.733726 -95.257593     98
# 22  2019-09-01  PM25      Texas  52.0  29.733726 -95.257593     98
# 23  2019-09-01    OZ      Texas  37.0  29.758889 -95.079444     99
# 24  2019-09-01    OZ  Louisiana  23.0  29.764098 -90.765275    100
# 25  2019-09-01    OZ      Texas  39.0  29.767997 -95.220582    101
# 26  2019-09-01  PM25      Texas  53.0  29.767997 -95.220582    101
# 27  2019-09-01  PM25      Texas  46.0  29.770698 -95.031232    102
# 28  2019-09-01    OZ      Texas  40.0  29.802707 -95.125495    103
# 29  2019-09-01    OZ      Texas  40.0  29.823319 -94.983786    105
# 30  2019-09-01    OZ      Texas  36.0  29.828086 -95.284096    106
# 31  2019-09-01    OZ      Texas  45.0  29.834167 -95.489167    107
# 32  2019-09-01    OZ      Texas  38.0  29.863957 -94.317802    108
# 33  2019-09-01  PM25      Texas  50.0  29.863957 -94.317802    108
# 34  2019-09-01    OZ      Texas  39.0  29.897516 -93.991084    109
# 35  2019-09-01    OZ      Texas  42.0  29.901036 -95.326137    111
# 36  2019-09-01  PM25      Texas  52.5  29.901036 -95.326137    111
# 37  2019-09-01  PM25      Texas  55.0  29.922894 -93.909018    112
# 38  2019-09-01    OZ  Louisiana  25.0  29.939614 -89.923883    113
# 39  2019-09-01    OZ      Texas  44.0  29.942500 -94.000556    114
# 40  2019-09-01    OZ      Texas  36.0  29.978926 -94.010872    116
# 41  2019-09-01    OZ  Louisiana  25.0  29.994970 -90.817415    117
# 42  2019-09-01    OZ      Texas  37.0  30.036422 -94.071061    119
# 43  2019-09-01    OZ      Texas  41.0  30.039524 -95.673951    120
# 44  2019-09-01    OZ  Louisiana  26.0  30.041238 -90.272826    121
# 45  2019-09-01    OZ  Louisiana  23.0  30.057515 -90.619286    122
# 46  2019-09-01    OZ      Texas  33.0  30.085263 -93.761341    123
# 47  2019-09-01    OZ  Louisiana  31.0  30.088872 -91.869595    124
# 48  2019-09-01    OZ    Florida  12.0  30.092500 -84.161111    125
# 49  2019-09-01    OZ    Florida  14.0  30.130433 -85.731517    126

# %%
cur.close()
conn.close()
